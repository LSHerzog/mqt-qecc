# %%
import matplotlib.pyplot as plt
import numpy as np

import mqt.qecc.co3 as co

plt.rcParams["font.family"] = "Times New Roman"

import pickle
from pathlib import Path

# %% [markdown]
# ## Only $q=24$

# %%
# hex factories

factories_q24_3 = [(0,2), (1,8), (5,1)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 24, factories_q24_3)
custom_layout_q24_3 = [data_qubit_locs, g]

factories_q24_4 = [(0,2), (1,8), (5,1), (8,6)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 24, factories_q24_4)
custom_layout_q24_4 = [data_qubit_locs, g]

factories_q42_3 = [(0,3), (0,7), (11,7)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 42, factories_q42_3)
custom_layout_q42_3 = [data_qubit_locs, g]

factories_q42_4 = [(0,3), (0,7), (11,7), (12,10)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 42, factories_q42_4)
custom_layout_q42_4 = [data_qubit_locs, g]

#row factories
factories_q24_3_row = [(0,2), (0,11), (0,15)]#, (4,1)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 24, factories_q24_3_row)
custom_layout_q24_3_row = [data_qubit_locs, g]

factories_q24_4_row = [(0,2), (0,11), (0,15), (4,1)]#, (6,10)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 24, factories_q24_4_row)
custom_layout_q24_4_row = [data_qubit_locs, g]

factories_q42_3_row = [(0,2), (0,11), (0,15)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 42, factories_q42_3_row)
custom_layout_q42_3_row = [data_qubit_locs, g]

factories_q42_4_row = [(0,2), (0,11), (0,15), (4,1)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 42, factories_q42_4_row)
custom_layout_q42_4_row = [data_qubit_locs, g]


#pair layout
factories_q24_3_pair = [(0,5), (0,9), (2,22)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("pair", 24, factories_q24_3_pair)
custom_layout_q24_3_pair = [data_qubit_locs, g]

factories_q24_4_pair = [(0,5), (0,9), (2,22), (8,18)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("pair", 24, factories_q24_4_pair)
custom_layout_q24_4_pair = [data_qubit_locs, g]


#sparse layout
factories_q24_3_sparse = [(0,5), (0,15), (0,21)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("sparse", 24, factories_q24_3_sparse)
custom_layout_q24_3_sparse = [data_qubit_locs, g]

factories_q24_4_sparse = [(0,5), (0,15), (0,21), (5,30)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("sparse", 24, factories_q24_4_sparse)
custom_layout_q24_4_sparse = [data_qubit_locs, g]

# %%
#where to store the data for plot
path = "./results/test_space_time_250218"

# %%
hc_params = {
    "metric" : "crossing",
    "max_restarts": 10,
    "max_iterations": 30,
    "routing" : "dynamic",
    "optimize_factories": False,
    "free_rows" : None,
    "parallel" : True,
    "processes" : 8
}

instances = [
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_3, "factory_locs" : factories_q24_3, "layout_type" : "custom", "layout_name": "hex"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_4, "factory_locs" : factories_q24_4,  "layout_type" : "custom", "layout_name": "hex"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_3_row, "factory_locs" : factories_q24_3_row,  "layout_type" : "custom", "layout_name": "row"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_4_row, "factory_locs" : factories_q24_4_row,  "layout_type" : "custom", "layout_name": "row"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_3_pair, "factory_locs" : factories_q24_3_pair,  "layout_type" : "custom", "layout_name": "pair"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_4_pair, "factory_locs" : factories_q24_4_pair,  "layout_type" : "custom", "layout_name": "pair"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_3_sparse, "factory_locs" : factories_q24_3_sparse,  "layout_type" : "custom", "layout_name": "sparse"},
    {"q": 24, "t": 3, "min_depth": 3*24, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_4_sparse, "factory_locs" : factories_q24_4_sparse,  "layout_type" : "custom", "layout_name": "sparse"},
]

reps = 3

res_lst = co.plots.collect_data_space_time(instances, hc_params, reps, path)
# Out:
# =======Instance 0=======
# ...
# Hill Climbing Restarts...: 100%|██████████| 10/10 [00:34<00:00,  3.43s/it]
# previous circuits kept
# =======Instance 1=======
# time [32, 26, 30]
# {'space': 88, 'time_mean': 29.333333333333332, 'time_std': 2.494438257849294}
# ...
# Hill Climbing Restarts...: 100%|██████████| 10/10 [00:29<00:00,  2.97s/it]
# previous circuits kept
# =======Instance 2=======
# time [34, 25, 31]
# {'space': 91, 'time_mean': 30.0, 'time_std': 3.7416573867739413}
# ...
# Hill Climbing Restarts...: 100%|██████████| 10/10 [00:37<00:00,  3.70s/it]
# previous circuits kept
# =======Instance 3=======
# time [32, 25, 28]
# {'space': 98, 'time_mean': 28.333333333333332, 'time_std': 2.8674417556808756}
# ...
# Hill Climbing Restarts...: 100%|██████████| 10/10 [00:43<00:00,  4.30s/it]
# previous circuits kept
# =======Instance 4=======
# time [29, 26, 27]
# {'space': 102, 'time_mean': 27.333333333333332, 'time_std': 1.247219128924647}
# ...

# %%
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)
# Out:
# KeyboardInterrupt

# %%
co.plots.plot_space_time(instances, hc_params, res_lst)

# %% [markdown]
# ### Big run ($q=24, 42, 60$)
#
# Here we want to use higher $t$ and therefore also more factories. Furthermore we want to vary the ratio as well as q
#
# Preliminary Plan:
#
# - hex, row, pair, sparse
# - t = 8 (fix)
# - #f = 8 (fix for now)
# - ratio = 0.5, 0.7, 0.9
# - q = 24, 42, 60

# %%
# --------- HEX --------------

#q=24
factories_q24_hex = [(0,3), (1,8), (2,13), (7,3), (8,8), (9,13), (4,2), (5,14)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 24, factories_q24_hex)
custom_layout_q24_hex = [data_qubit_locs, g]

#q=42
factories_q42_hex = [(0,3), (1,8), (2,13), (12,12), (3,18), (11,9), (10,4), (7,3)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 42, factories_q42_hex)
custom_layout_q42_hex = [data_qubit_locs, g]

#q=60
factories_q60_hex = [(0,3), (1,8), (2,13), (12,12), (3,18), (11,9), (10,4), (13,17)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("hex", 60, factories_q60_hex)
custom_layout_q60_hex = [data_qubit_locs, g]

#------------- ROW -------------

#q=24
factories_q24_row = [(0,3), (0,9), (0,15), (6,6), (6,12), (6,18), (5,3), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 24, factories_q24_row)
custom_layout_q24_row = [data_qubit_locs, g]

#q=42 #same factories
factories_q42_row = [(0,3), (0,9), (0,15), (6,6), (6,12), (6,18), (5,3), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 42, factories_q42_row)
custom_layout_q42_row = [data_qubit_locs, g]

#q=60 # same factories
factories_q60_row = [(0,3), (0,9), (0,15), (6,6), (6,12), (6,18), (5,3), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("row", 60, factories_q60_row)
custom_layout_q60_row = [data_qubit_locs, g]

#----------- PAIR ---------------

#q=24
factories_q24_pair = [(0,5), (0,11), (0,17), (7,3), (8,8), (8,14), (8,20), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("pair", 24, factories_q24_pair)
custom_layout_q24_pair = [data_qubit_locs, g]

#q=42 #duplicate factories
factories_q42_pair = [(0,5), (0,11), (0,17), (7,3), (8,8), (8,14), (8,20), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("pair", 42, factories_q42_pair)
custom_layout_q42_pair = [data_qubit_locs, g]

#q=60 #duplicate factories
factories_q60_pair = [(0,5), (0,11), (0,17), (7,3), (8,8), (8,14), (8,20), (2,2)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("pair", 60, factories_q60_pair)
custom_layout_q60_pair = [data_qubit_locs, g]


# --------- sparse -------------

#q=24
factories_q24_sparse = [(0,5), (0,15), (0,21), (5,30), (8,29), (9,21), (8,11), (6,1)]
g, data_qubit_locs, factory_ring = co.plots.gen_layout("sparse", 24, factories_q24_sparse)
custom_layout_q24_sparse = [data_qubit_locs, g]

# %%
path = "./results/test_250219_q24_42_60_f"

# %%
hc_params = {
    "metric" : "crossing",
    "max_restarts": 15,
    "max_iterations": 50,
    "routing" : "dynamic",
    "optimize_factories": False,
    "free_rows" : None,
    "parallel" : True,
    "processes" : 8
}

instances = [
    # be aware of order such that same params not multiple samples
    
    #q=24
    #ratio = 0.9
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_hex, "factory_locs" : factories_q24_hex, "layout_type" : "custom", "layout_name": "hex"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_row, "factory_locs" : factories_q24_row, "layout_type" : "custom", "layout_name": "row"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_pair, "factory_locs" : factories_q24_pair, "layout_type" : "custom", "layout_name": "pair"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q24_sparse, "factory_locs" : factories_q24_sparse, "layout_type" : "custom", "layout_name": "sparse"},

    #ratio = 0.7
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q24_hex, "factory_locs" : factories_q24_hex, "layout_type" : "custom", "layout_name": "hex"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q24_row, "factory_locs" : factories_q24_row, "layout_type" : "custom", "layout_name": "row"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q24_pair, "factory_locs" : factories_q24_pair, "layout_type" : "custom", "layout_name": "pair"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q24_sparse, "factory_locs" : factories_q24_sparse, "layout_type" : "custom", "layout_name": "sparse"},

    #ratio = 0.5
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q24_hex, "factory_locs" : factories_q24_hex, "layout_type" : "custom", "layout_name": "hex"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q24_row, "factory_locs" : factories_q24_row, "layout_type" : "custom", "layout_name": "row"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q24_pair, "factory_locs" : factories_q24_pair, "layout_type" : "custom", "layout_name": "pair"},
    {"q": 24, "t": 8, "min_depth": 24*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q24_sparse, "factory_locs" : factories_q24_sparse, "layout_type" : "custom", "layout_name": "sparse"},


    #q=42
    #ratio = 0.9
    {"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q42_hex, "factory_locs" : factories_q42_hex, "layout_type" : "custom", "layout_name": "hex"},
    {"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q42_row, "factory_locs" : factories_q42_row, "layout_type" : "custom", "layout_name": "row"},
    {"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q42_pair, "factory_locs" : factories_q42_pair, "layout_type" : "custom", "layout_name": "pair"},

    #ratio = 0.7
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q42_hex, "factory_locs" : factories_q42_hex, "layout_type" : "custom", "layout_name": "hex"},
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q42_row, "factory_locs" : factories_q42_row, "layout_type" : "custom", "layout_name": "row"},
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q42_pair, "factory_locs" : factories_q42_pair, "layout_type" : "custom", "layout_name": "pair"},

    #ratio = 0.5
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q42_hex, "factory_locs" : factories_q42_hex, "layout_type" : "custom", "layout_name": "hex"},
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q42_row, "factory_locs" : factories_q42_row, "layout_type" : "custom", "layout_name": "row"},
    #{"q": 42, "t": 8, "min_depth": 42*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q42_pair, "factory_locs" : factories_q42_pair, "layout_type" : "custom", "layout_name": "pair"},

    #q=60
    #ratio = 0.9
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q60_hex, "factory_locs" : factories_q60_hex, "layout_type" : "custom", "layout_name": "hex"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q60_row, "factory_locs" : factories_q60_row, "layout_type" : "custom", "layout_name": "row"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.9, "custom_layout": custom_layout_q60_pair, "factory_locs" : factories_q60_pair, "layout_type" : "custom", "layout_name": "pair"},

    #ratio = 0.7
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q60_hex, "factory_locs" : factories_q60_hex, "layout_type" : "custom", "layout_name": "hex"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q60_row, "factory_locs" : factories_q60_row, "layout_type" : "custom", "layout_name": "row"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.7, "custom_layout": custom_layout_q60_pair, "factory_locs" : factories_q60_pair, "layout_type" : "custom", "layout_name": "pair"},
    
    #ratio = 0.5
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q60_hex, "factory_locs" : factories_q60_hex, "layout_type" : "custom", "layout_name": "hex"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q60_row, "factory_locs" : factories_q60_row, "layout_type" : "custom", "layout_name": "row"},
    #{"q": 60, "t": 8, "min_depth": 60*4, "tgate": True, "ratio": 0.5, "custom_layout": custom_layout_q60_pair, "factory_locs" : factories_q60_pair, "layout_type" : "custom", "layout_name": "pair"},

]

# %%
reps = 8 #less is a bit weird

#res_lst = co.plots.collect_data_space_time(instances, hc_params, reps, path)

# %% [markdown]
# Plot runs from server here

# %%
import matplotlib.pyplot as plt
import numpy as np

import mqt.qecc.co3 as co

plt.rcParams["font.family"] = "Times New Roman"

import pickle
from pathlib import Path

# %%
path = "/mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/results/test_250221_q24_42_60_8restarts"

# %%
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
for i,res in enumerate(res_lst):
    layout_type = res["instances"][i]["layout_name"]
    q = res["instances"][i]["q"]
    ratio = res["instances"][i]["ratio"]
    num_init_list = res["num_init_lst"]
    num_final_list = res["num_final_lst"]
    improvement_lst = []
    for ni, nf in zip(num_init_list, num_final_list):
        improvement_lst.append((ni-nf)/ni)
    print("Layout", layout_type, "q", q, "ratio", ratio)
    print("mean imporvement", np.mean(improvement_lst), "std", np.std(improvement_lst))
# Out:
# Layout hex q 24 ratio 0.9
# mean imporvement 0.20790982761944649 std 0.04610948929352456
# Layout row q 24 ratio 0.9
# mean imporvement 0.1499346405228758 std 0.050294701589614584
# Layout pair q 24 ratio 0.9
# mean imporvement 0.05945054945054945 std 0.055564469491104225
# Layout sparse q 24 ratio 0.9
# mean imporvement -0.006282598387861546 std 0.04609515516704828
# Layout hex q 24 ratio 0.7
# mean imporvement 0.055279708705726585 std 0.05809954128423004
# Layout row q 24 ratio 0.7
# mean imporvement 0.06132327089773898 std 0.06644538715163006
# Layout pair q 24 ratio 0.7
# mean imporvement 0.00019762845849802396 std 0.014063594367317942
# Layout sparse q 24 ratio 0.7
# mean imporvement 0.014174972314507197 std 0.018993458759263206
# Layout hex q 24 ratio 0.5
# mean imporvement 0.050294020770363476 std 0.048763440202051755
# Layout row q 24 ratio 0.5
# mean imporvement 0.02598598744708802 std 0.05368063033547635
# Layout pair q 24 ratio 0.5
# ...

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
co.plots.plot_space_time(instances, hc_params, res_lst)

# %% [markdown]
# ## Load Results from Server Runs and refine the plots

# %%
import matplotlib.pyplot as plt
import numpy as np

import mqt.qecc.co3 as co

plt.rcParams["font.family"] = "Times New Roman"

import pickle
from pathlib import Path

# %%
# from server results: /home/herzog/color_code_compilation/mqt-qecc/src/mqt/qecc/co3/plots/space_time_plots_big.py
path = "./results/test_250221_q24_42_60_8restarts"

with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
#check improvements from hc. not too high for small ratios and sparser layouts.
for i,res in enumerate(res_lst):
    layout_type = res["instances"][i]["layout_name"]
    q = res["instances"][i]["q"]
    ratio = res["instances"][i]["ratio"]
    num_init_list = res["num_init_lst"]
    num_final_list = res["num_final_lst"]
    improvement_lst = []
    for ni, nf in zip(num_init_list, num_final_list):
        improvement_lst.append((ni-nf)/ni)
    print("Layout", layout_type, "q", q, "ratio", ratio)
    print("mean imporvement", np.mean(improvement_lst), "std", np.std(improvement_lst))
# Out:
# Layout hex q 24 ratio 0.9
# mean imporvement 0.20790982761944649 std 0.04610948929352456
# Layout row q 24 ratio 0.9
# mean imporvement 0.1499346405228758 std 0.050294701589614584
# Layout pair q 24 ratio 0.9
# mean imporvement 0.05945054945054945 std 0.055564469491104225
# Layout sparse q 24 ratio 0.9
# mean imporvement -0.006282598387861546 std 0.04609515516704828
# Layout hex q 24 ratio 0.7
# mean imporvement 0.055279708705726585 std 0.05809954128423004
# Layout row q 24 ratio 0.7
# mean imporvement 0.06132327089773898 std 0.06644538715163006
# Layout pair q 24 ratio 0.7
# mean imporvement 0.00019762845849802396 std 0.014063594367317942
# Layout sparse q 24 ratio 0.7
# mean imporvement 0.014174972314507197 std 0.018993458759263206
# Layout hex q 24 ratio 0.5
# mean imporvement 0.050294020770363476 std 0.048763440202051755
# Layout row q 24 ratio 0.5
# mean imporvement 0.02598598744708802 std 0.05368063033547635
# Layout pair q 24 ratio 0.5
# ...

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
size = (4.5,4.5)
co.plots.plot_space_time(instances, hc_params, res_lst, size=size)

# %%
# factories v.s. time from
#/home/herzog/color_code_compilation/mqt-qecc/src/mqt/qecc/co3/plots/f_v_s_time_q24.py

path = "./results/f_vs_time_q24_ratio08"

with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
size = (4,4)
q=24
ratio=0.8
layout_name = "hex"
min_depth = 4*q
co.plots.plot_f_vs_t(res_lst, q, ratio, layout_name, min_depth)
# Out:
# data [[0.08166599 0.20815018 0.14429998 0.02663186]
#  [0.12751323 0.17156986 0.18552127 0.12637242]
#  [0.23463768 0.17297852 0.21639355 0.15119682]
#  [0.18037197 0.2006984  0.19298942 0.08518519]]
# data_abs [[40.66666667 41.66666667 51.         66.33333333]
#  [38.33333333 41.66666667 46.66666667 56.66666667]
#  [36.66666667 41.33333333 44.33333333 53.33333333]
#  [36.         40.33333333 44.33333333 53.        ]]
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:456: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:517: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# factories v.s. time from
#/home/herzog/color_code_compilation/mqt-qecc/src/mqt/qecc/co3/plots/f_v_s_time_q42.py

path = "./results/f_vs_time_q42_ratio08"

with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
size = (4,4)
q=42
ratio=0.8
layout_name = "hex"
min_depth = 4*q
co.plots.plot_f_vs_t(res_lst, q, ratio, layout_name, min_depth, size=size)
# Out:
# data [[0.1372519  0.01731715 0.01686345 0.00047281]
#  [0.16537331 0.14917586 0.08532883 0.03435796]
#  [0.13226338 0.18921294 0.10422892 0.05712647]
#  [0.17974803 0.13993009 0.16192447 0.12340176]
#  [0.17530584 0.17421009 0.13163989 0.16477992]]
# data_abs [[ 66.4 151.6 282.8 421.2]
#  [ 61.4  69.6  98.4 128.8]
#  [ 61.   62.4  73.4  91.6]
#  [ 59.6  64.8  67.8  75.4]
#  [ 58.8  62.8  68.8  70.8]]
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:456: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:517: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# factories v.s. time from
#/home/herzog/color_code_compilation/mqt-qecc/src/mqt/qecc/co3/plots/f_v_s_time_q42.py

path = "./results/f_vs_time_q42_ratio08_row"

with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
size = (4,4)
q=42
ratio=0.8
layout_name = "row"#"hex"
min_depth = 4*q
co.plots.plot_f_vs_t(res_lst, q, ratio, layout_name, min_depth, size=size)
# Out:
# data [[0.17119336 0.04060761 0.00070922 0.        ]
#  [0.17384675 0.0666726  0.02539389 0.0805563 ]
#  [0.15859783 0.14485211 0.12757684 0.11776172]
#  [0.15432924 0.10821392 0.09870222 0.12891759]
#  [0.16033236 0.15448724 0.12713078 0.10799201]]
# data_abs [[ 62.2 145.4 281.  421. ]
#  [ 60.6  70.6  94.  119.2]
#  [ 57.2  63.   71.2  82.8]
#  [ 56.6  62.4  68.6  72. ]
#  [ 55.2  59.   64.8  70.4]]
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:456: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# /mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/evaluation.py:517: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
# ratio vs time from 
#/home/herzog/color_code_compilation/mqt-qecc/src/mqt/qecc/co3/plots/ratio_vs_time_q42.py
path = "./results/ratio_vs_time_q42_f13"
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
instances = res_lst[0]["instances"]
hc_params = res_lst[0]["hc_params"]
size = (4.5,4.5)
q=42
num_factories = 13
layout_name = "hex"
min_depth = 4*q
co.plots.plot_ratio_vs_t(res_lst, q, num_factories, layout_name, min_depth, size=size)
# Out:
# data [[0.12625162 0.1710601  0.21701986 0.1658793 ]
#  [0.21082479 0.18673521 0.19405535 0.16293818]
#  [0.13985794 0.08888102 0.18865484 0.04469645]
#  [0.19521258 0.19562582 0.1732872  0.15126714]
#  [0.19599279 0.13707319 0.13904339 0.07784903]]
# data_std [[0.0624302  0.04725967 0.0892915  0.06843762]
#  [0.03930085 0.04267658 0.07300942 0.0634021 ]
#  [0.04735555 0.03874493 0.07165757 0.05214894]
#  [0.04947804 0.04516397 0.05454421 0.07081419]
#  [0.01812281 0.03201253 0.03288701 0.04427116]]

# %%
from mqt.qecc import co3 as co
import random

# %%
q=6
min_depth = 2*6
circuit = co.generate_max_parallel_circuit(q, min_depth)
print(circuit)
# Out:
# [(5, 3), (1, 4), (2, 0), (3, 4), (5, 0), (2, 1), (2, 1), (4, 0), (5, 3), (3, 2), (5, 4), (0, 1)]

# %%
q=42
min_depth = q*4
layer_size = 2
circuit = co.generate_min_parallel_circuit(q, min_depth, layer_size)
print(len(circuit))
print(min_depth)
print(circuit)
# Out:
# 168
# 168
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

import mqt.qecc.co3 as co

plt.rcParams["font.family"] = "Times New Roman"

import pickle
from pathlib import Path

# %%
#path = "/mnt/c/Users/Laura/Documents/mqt-qecc/test.pkl"
#q=24
path = "/mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/results/compare_circuit_types_hc_depths.pkl"
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
#res_lst = res_lst[:18]

# %%
size = (4,4)
co.plots.plot_improvement_circuit_types(res_lst[18:27], size=size)
# Out:
# {'i': 0, 'mean_final_layers': 82.8, 'std_final_layers': 2.638181191654584, 'mean_improvement': 0.13948530935007805, 'std_improvement': 0.03784607608973441, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'hex', 'min_depth': 48}
# {'i': 1, 'mean_final_layers': 78.0, 'std_final_layers': 2.6832815729997477, 'mean_improvement': 0.17498088359374203, 'std_improvement': 0.029609564493895024, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'row', 'min_depth': 48}
# {'i': 2, 'mean_final_layers': 65.4, 'std_final_layers': 4.454211490264018, 'mean_improvement': 0.03570789380129775, 'std_improvement': 0.020852232955242984, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'pair', 'min_depth': 48}
# ...

# %%
#path = "/mnt/c/Users/Laura/Documents/mqt-qecc/test.pkl"
path = "/mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/results/compare_circuit_types_hc_depths_q42.pkl"
#q=42 and different depths
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
size = (4,4)
co.plots.plot_improvement_circuit_types(res_lst[:9], size=size)
#depth=2q
# Out:
# {'i': 0, 'mean_final_layers': 31.8, 'std_final_layers': 1.469693845669907, 'mean_improvement': 0.22356035437430788, 'std_improvement': 0.04395628752414636, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'hex', 'min_depth': 84}
# {'i': 1, 'mean_final_layers': 30.6, 'std_final_layers': 2.1540659228538015, 'mean_improvement': 0.18584819637451216, 'std_improvement': 0.058906911244089526, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'row', 'min_depth': 84}
# {'i': 2, 'mean_final_layers': 24.4, 'std_final_layers': 2.244994432064365, 'mean_improvement': 0.10116326782845135, 'std_improvement': 0.0550742408647008, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'pair', 'min_depth': 84}
# ...

# %%
size = (4,4)
co.plots.plot_improvement_circuit_types(res_lst[9:18], size=size)
#depth=4q
# Out:
# {'i': 0, 'mean_final_layers': 64.6, 'std_final_layers': 4.223742416388575, 'mean_improvement': 0.180697026503648, 'std_improvement': 0.04129570409854218, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'hex', 'min_depth': 84}
# {'i': 1, 'mean_final_layers': 60.6, 'std_final_layers': 1.4966629547095764, 'mean_improvement': 0.1873417803768681, 'std_improvement': 0.053606695979297125, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'row', 'min_depth': 84}
# {'i': 2, 'mean_final_layers': 45.0, 'std_final_layers': 1.4142135623730951, 'mean_improvement': 0.147303571670168, 'std_improvement': 0.04695385020744317, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'pair', 'min_depth': 84}
# ...

# %%
size = (4,4)
co.plots.plot_improvement_circuit_types(res_lst[18:27], size=size)
#depth=8q
# Out:
# {'i': 0, 'mean_final_layers': 135.0, 'std_final_layers': 5.019960159204453, 'mean_improvement': 0.1482127561694612, 'std_improvement': 0.04203667817305959, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'hex', 'min_depth': 84}
# {'i': 1, 'mean_final_layers': 126.8, 'std_final_layers': 2.9257477676655586, 'mean_improvement': 0.14236702045916702, 'std_improvement': 0.033574964665793544, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'row', 'min_depth': 84}
# {'i': 2, 'mean_final_layers': 90.0, 'std_final_layers': 1.7888543819998317, 'mean_improvement': 0.11343022584670996, 'std_improvement': 0.02527453751005103, 't': 4, 'factory_locs': [], 'q': 42, 'circuit_type': 'random', 'layout_name': 'pair', 'min_depth': 84}
# ...

# %%
#path = "/mnt/c/Users/Laura/Documents/mqt-qecc/test.pkl"
path = "/mnt/c/Users/Laura/Documents/mqt-qecc/src/mqt/qecc/co3/plots/results/compare_circuit_types_hc_depths_q24.pkl"
#q=42 and different depths
with Path(path).open("rb") as f:
    res_lst = pickle.load(f)

# %%
size = (4,4)
co.plots.plot_improvement_circuit_types(res_lst, size=size)
#depth=2q
# Out:
# {'i': 0, 'mean_final_layers': 39.76, 'std_final_layers': 2.121885953579975, 'mean_improvement': 0.19409877993132527, 'std_improvement': 0.0689403331790389, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'hex', 'min_depth': 96}
# {'i': 1, 'mean_final_layers': 38.32, 'std_final_layers': 2.1673947494630506, 'mean_improvement': 0.1735004414728247, 'std_improvement': 0.06815314210092585, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'row', 'min_depth': 96}
# {'i': 2, 'mean_final_layers': 33.8, 'std_final_layers': 2.3065125189341593, 'mean_improvement': 0.035267388495008746, 'std_improvement': 0.03900200717645319, 't': 4, 'factory_locs': [], 'q': 24, 'circuit_type': 'random', 'layout_name': 'pair', 'min_depth': 96}
# ...
